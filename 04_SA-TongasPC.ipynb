# %% [markdown]
# # Uncertainty analysis

# %%
from SA_all import SA
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

from plots import *
pd.set_option('display.max_columns', None)

# Define the variables and their possible values
site = 'P'

clls = [0.2, 0.3]
percents = [10, 20, 30]
sample_locs = ['mean', 'closest']
interfaces = ['observed', 'log-defined']
FMs = ['FSeq', 'CS', 'FSlin']
MinMs = ['Gauss-Newton', 'ROPE']
alphas = [0.01, 0.07, 0.2]
remove_coils = [True, False]
start_avgs = [True, False]
constrains = [True, False]

SA_results = 'SA_results/'

file_path_all = 'dt'+site+'_'+str(clls)+'_'+str(percents)+'_'+str(sample_locs)+'_'+str(['obs', 'logd'])+'_'+str(FMs)+'_'+str(['GN', 'ROPE'])+'_'+str(alphas)+'_'+str(['T', 'F'])+'_'+str(['T', 'F'])+'_'+str(['T', 'F'])+'_det'

# Initialize DataFrame
dt = pd.DataFrame()
i = 0  # to keep track of iterations for saving purposes

# Iterate over all combinations
for combination in itertools.product(clls, percents, sample_locs, interfaces, FMs, MinMs, alphas, remove_coils, start_avgs, constrains):

    cl, percent, sample_loc, interface, FM, MinM, alpha, remove_coil, start_avg, constrain = combination
    print('Iteration:', i, 'Combination:', combination)

    file_path = 'dt'+site+'_'+str(cl)+'_'+str(percent)+'_'+str(sample_loc)+'_'+str(interface)+'_'+str(FM)+'_'+str(MinM)+'_'+str(alpha)+'_'+str(remove_coil)+'_'+str(start_avg)+'_'+str(constrain)+'_det'
    SA_file_path = SA_results + file_path+'.csv'
    file_path_FAILED = SA_results + file_path+'_FAILED'+'.csv'

    if os.path.exists(SA_file_path):
        #print('exists')
        SA_file = pd.read_csv(SA_file_path)

    elif os.path.exists(file_path_FAILED):
        #print('exists but failed')

        SA_file_FAILED = pd.read_csv(file_path_FAILED)

    else:
        try:
            # Call the SA function with the current combination
            results = SA(site, cl, percent, sample_loc, interface, FM, MinM, alpha, remove_coil, start_avg, constrain)

            # Create a dictionary for the current iteration's results
            current_results = [{'cl': cl, 'percent': percent, 'Samples location': sample_loc, 'Interface': interface, 'Forward_Model': FM, 'Minimization_Method': MinM, 'Alpha': alpha,
                                'remove_coil': remove_coil, 'start_avg': start_avg, 'constrain': constrain,
                                'Det': det, 'R2': res[0], 'RMSE': res[1], '0R2': res[2], '0RMSE': res[3]}
                            for det, res in zip(['LT', 'ID', 'LS'], [(results[i], results[i+1], results[i+10], results[i+11]) for i in range(0, 6, 2)])]

            print('current_results', current_results)
            SA_file = pd.DataFrame(current_results)
            # Save the DataFrame to CSV after each iteration
            SA_file.to_csv(SA_file_path, index=False)

        except Exception as e:

            # Create a dictionary for the current iteration's results
            current_results = [{'cl': cl, 'percent': percent, 'Samples location': sample_loc, 'Interface': interface, 'Forward_Model': FM, 'Minimization_Method': MinM, 'Alpha': alpha,
                                'remove_coil': remove_coil, 'start_avg': start_avg, 'constrain': constrain,
                                'Det': det, 'R2': np.nan, 'RMSE': np.nan, '0R2': np.nan, '0RMSE': np.nan}
                            for det, res in zip(['LT', 'ID', 'LS'], [(np.nan, np.nan, np.nan, np.nan) for i in range(0, 6, 2)])]
            
            SA_file_FAILED = pd.DataFrame(current_results)
            #print(f"An error occurred: {e} with combination {combination}")
            SA_file_FAILED.to_csv(file_path_FAILED, index=False)

            continue  # Continue to the next iteration even if an error occurs

    #print('SA_file.head()', SA_file.head())
    #print('dt', dt.head())
    # Append current results to the DataFrame
    dt = pd.concat([dt, SA_file])
    i += 1  # Increment the iteration counter

print(dt)
dt.to_csv(SA_results + file_path_all+'.csv')
# Out:
# Iteration: 0 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 1 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 2 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 3 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 4 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 5 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 6 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 7 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 8 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 9 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 10 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 11 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 12 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 13 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 14 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 15 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 16 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 17 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 18 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 19 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 20 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 21 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 22 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 23 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 24 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, True, True)
# Iteration: 25 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, True, False)
# Iteration: 26 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, False, True)
# Iteration: 27 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, False, False)
# Iteration: 28 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, True, True)
# Iteration: 29 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, True, False)
# Iteration: 30 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, False, True)
# Iteration: 31 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, False, False)
# Iteration: 32 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, True, True)
# Iteration: 33 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, True, False)
# Iteration: 34 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, False, True)
# Iteration: 35 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, False, False)
# Iteration: 36 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, True, True)
# Iteration: 37 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, True, False)
# Iteration: 38 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, False, True)
# Iteration: 39 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, False, False)
# Iteration: 40 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, True, True)
# Iteration: 41 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, True, False)
# Iteration: 42 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, False, True)
# Iteration: 43 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, False, False)
# Iteration: 44 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, True, True)
# Iteration: 45 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, True, False)
# Iteration: 46 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, False, True)
# Iteration: 47 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, False, False)
# Iteration: 48 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 49 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 50 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 51 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 52 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 53 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 54 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 55 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 56 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 57 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 58 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 59 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 60 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 61 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 62 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 63 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 64 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 65 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 66 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 67 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 68 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 69 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 70 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 71 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 72 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, True, True)
# Iteration: 73 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, True, False)
# Iteration: 74 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, False, True)
# Iteration: 75 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, False, False)
# Iteration: 76 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, True, True)
# Iteration: 77 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, True, False)
# Iteration: 78 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, False, True)
# Iteration: 79 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, False, False)
# Iteration: 80 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, True, True)
# Iteration: 81 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, True, False)
# Iteration: 82 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, False, True)
# Iteration: 83 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, False, False)
# Iteration: 84 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, True, True)
# Iteration: 85 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, True, False)
# Iteration: 86 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, False, True)
# Iteration: 87 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, False, False)
# Iteration: 88 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, True, True)
# Iteration: 89 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, True, False)
# Iteration: 90 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, False, True)
# Iteration: 91 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, False, False)
# Iteration: 92 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, True, True)
# Iteration: 93 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, True, False)
# Iteration: 94 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, False, True)
# Iteration: 95 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, False, False)
# Iteration: 96 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 97 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 98 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 99 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 100 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 101 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 102 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 103 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 104 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 105 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 106 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 107 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 108 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 109 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 110 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 111 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 112 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 113 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 114 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 115 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 116 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 117 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 118 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 119 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 120 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, True, True)
# Iteration: 121 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, True, False)
# Iteration: 122 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, False, True)
# Iteration: 123 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, False, False)
# Iteration: 124 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, True, True)
# Iteration: 125 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, True, False)
# Iteration: 126 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, False, True)
# Iteration: 127 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, False, False)
# Iteration: 128 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, True, True)
# Iteration: 129 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, True, False)
# Iteration: 130 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, False, True)
# Iteration: 131 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, False, False)
# Iteration: 132 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, True, True)
# Iteration: 133 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, True, False)
# Iteration: 134 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, False, True)
# Iteration: 135 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, False, False)
# Iteration: 136 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, True, True)
# Iteration: 137 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, True, False)
# Iteration: 138 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, False, True)
# Iteration: 139 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, False, False)
# Iteration: 140 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, True, True)
# Iteration: 141 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, True, False)
# Iteration: 142 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, False, True)
# Iteration: 143 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, False, False)
# Iteration: 144 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 145 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 146 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 147 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 148 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 149 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 150 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 151 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 152 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 153 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 154 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 155 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 156 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 157 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 158 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 159 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 160 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 161 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 162 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 163 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 164 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 165 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 166 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 167 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 168 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, True, True, True)
# Iteration: 169 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, True, True, False)
# Iteration: 170 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, True, False, True)
# Iteration: 171 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, True, False, False)
# Iteration: 172 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, False, True, True)
# Iteration: 173 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, False, True, False)
# Iteration: 174 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, False, False, True)
# Iteration: 175 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.01, False, False, False)
# Iteration: 176 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, True, True, True)
# Iteration: 177 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, True, True, False)
# Iteration: 178 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, True, False, True)
# Iteration: 179 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, True, False, False)
# Iteration: 180 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, False, True, True)
# Iteration: 181 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, False, True, False)
# Iteration: 182 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, False, False, True)
# Iteration: 183 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.07, False, False, False)
# Iteration: 184 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, True, True, True)
# Iteration: 185 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, True, True, False)
# Iteration: 186 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, True, False, True)
# Iteration: 187 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, True, False, False)
# Iteration: 188 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, False, True, True)
# Iteration: 189 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, False, True, False)
# Iteration: 190 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, False, False, True)
# Iteration: 191 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'ROPE', 0.2, False, False, False)
# Iteration: 192 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 193 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 194 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 195 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 196 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 197 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 198 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 199 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 200 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 201 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 202 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 203 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 204 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 205 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 206 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 207 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 208 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 209 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 210 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 211 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 212 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 213 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 214 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 215 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 216 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, True, True, True)
# Iteration: 217 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, True, True, False)
# Iteration: 218 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, True, False, True)
# Iteration: 219 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, True, False, False)
# Iteration: 220 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, False, True, True)
# Iteration: 221 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, False, True, False)
# Iteration: 222 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, False, False, True)
# Iteration: 223 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.01, False, False, False)
# Iteration: 224 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, True, True, True)
# Iteration: 225 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, True, True, False)
# Iteration: 226 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, True, False, True)
# Iteration: 227 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, True, False, False)
# Iteration: 228 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, False, True, True)
# Iteration: 229 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, False, True, False)
# Iteration: 230 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, False, False, True)
# Iteration: 231 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.07, False, False, False)
# Iteration: 232 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, True, True, True)
# Iteration: 233 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, True, True, False)
# Iteration: 234 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, True, False, True)
# Iteration: 235 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, True, False, False)
# Iteration: 236 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, False, True, True)
# Iteration: 237 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, False, True, False)
# Iteration: 238 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, False, False, True)
# Iteration: 239 Combination: (0.2, 10, 'mean', 'log-defined', 'CS', 'ROPE', 0.2, False, False, False)
# Iteration: 240 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 241 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 242 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 243 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 244 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 245 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 246 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 247 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 248 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 249 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 250 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 251 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 252 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 253 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 254 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 255 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 256 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 257 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 258 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 259 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 260 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 261 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 262 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 263 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 264 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, True, True, True)
# Iteration: 265 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, True, True, False)
# Iteration: 266 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, True, False, True)
# Iteration: 267 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, True, False, False)
# Iteration: 268 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, False, True, True)
# Iteration: 269 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, False, True, False)
# Iteration: 270 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, False, False, True)
# Iteration: 271 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.01, False, False, False)
# Iteration: 272 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, True, True, True)
# Iteration: 273 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, True, True, False)
# Iteration: 274 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, True, False, True)
# Iteration: 275 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, True, False, False)
# Iteration: 276 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, False, True, True)
# Iteration: 277 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, False, True, False)
# Iteration: 278 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, False, False, True)
# Iteration: 279 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.07, False, False, False)
# Iteration: 280 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, True, True, True)
# Iteration: 281 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, True, True, False)
# Iteration: 282 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, True, False, True)
# Iteration: 283 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, True, False, False)
# Iteration: 284 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, False, True, True)
# Iteration: 285 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, False, True, False)
# Iteration: 286 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, False, False, True)
# Iteration: 287 Combination: (0.2, 10, 'mean', 'log-defined', 'FSlin', 'ROPE', 0.2, False, False, False)
# Iteration: 288 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 289 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 290 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 291 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 292 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 293 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 294 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 295 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 296 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 297 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 298 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 299 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 300 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 301 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 302 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 303 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 304 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 305 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 306 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 307 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 308 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 309 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 310 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 311 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 312 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, True, True, True)
# Iteration: 313 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, True, True, False)
# Iteration: 314 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, True, False, True)
# Iteration: 315 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, True, False, False)
# Iteration: 316 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, False, True, True)
# Iteration: 317 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, False, True, False)
# Iteration: 318 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, False, False, True)
# Iteration: 319 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.01, False, False, False)
# Iteration: 320 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, True, True, True)
# Iteration: 321 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, True, True, False)
# Iteration: 322 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, True, False, True)
# Iteration: 323 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, True, False, False)
# Iteration: 324 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, False, True, True)
# Iteration: 325 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, False, True, False)
# Iteration: 326 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, False, False, True)
# Iteration: 327 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.07, False, False, False)
# Iteration: 328 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, True, True, True)
# Iteration: 329 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, True, True, False)
# Iteration: 330 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, True, False, True)
# Iteration: 331 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, True, False, False)
# Iteration: 332 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, False, True, True)
# Iteration: 333 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, False, True, False)
# Iteration: 334 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, False, False, True)
# Iteration: 335 Combination: (0.2, 10, 'closest', 'observed', 'FSeq', 'ROPE', 0.2, False, False, False)
# Iteration: 336 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 337 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 338 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 339 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 340 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 341 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 342 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 343 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 344 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 345 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 346 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 347 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 348 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 349 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 350 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 351 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 352 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 353 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 354 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 355 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 356 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 357 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 358 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 359 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 360 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, True, True, True)
# Iteration: 361 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, True, True, False)
# Iteration: 362 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, True, False, True)
# Iteration: 363 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, True, False, False)
# Iteration: 364 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, False, True, True)
# Iteration: 365 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, False, True, False)
# Iteration: 366 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, False, False, True)
# Iteration: 367 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.01, False, False, False)
# Iteration: 368 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, True, True, True)
# Iteration: 369 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, True, True, False)
# Iteration: 370 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, True, False, True)
# Iteration: 371 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, True, False, False)
# Iteration: 372 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, False, True, True)
# Iteration: 373 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, False, True, False)
# Iteration: 374 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, False, False, True)
# Iteration: 375 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.07, False, False, False)
# Iteration: 376 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, True, True, True)
# Iteration: 377 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, True, True, False)
# Iteration: 378 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, True, False, True)
# Iteration: 379 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, True, False, False)
# Iteration: 380 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, False, True, True)
# Iteration: 381 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, False, True, False)
# Iteration: 382 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, False, False, True)
# Iteration: 383 Combination: (0.2, 10, 'closest', 'observed', 'CS', 'ROPE', 0.2, False, False, False)
# Iteration: 384 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 385 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 386 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 387 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 388 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 389 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 390 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 391 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 392 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 393 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 394 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 395 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 396 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 397 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 398 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 399 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 400 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 401 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 402 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 403 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 404 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 405 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 406 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 407 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 408 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, True, True, True)
# Iteration: 409 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, True, True, False)
# Iteration: 410 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, True, False, True)
# Iteration: 411 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, True, False, False)
# Iteration: 412 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, False, True, True)
# Iteration: 413 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, False, True, False)
# Iteration: 414 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, False, False, True)
# Iteration: 415 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.01, False, False, False)
# Iteration: 416 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, True, True, True)
# Iteration: 417 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, True, True, False)
# Iteration: 418 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, True, False, True)
# Iteration: 419 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, True, False, False)
# Iteration: 420 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, False, True, True)
# Iteration: 421 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, False, True, False)
# Iteration: 422 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, False, False, True)
# Iteration: 423 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.07, False, False, False)
# Iteration: 424 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, True, True, True)
# Iteration: 425 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, True, True, False)
# Iteration: 426 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, True, False, True)
# Iteration: 427 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, True, False, False)
# Iteration: 428 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, False, True, True)
# Iteration: 429 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, False, True, False)
# Iteration: 430 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, False, False, True)
# Iteration: 431 Combination: (0.2, 10, 'closest', 'observed', 'FSlin', 'ROPE', 0.2, False, False, False)
# Iteration: 432 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 433 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 434 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 435 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 436 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 437 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 438 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 439 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 440 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 441 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 442 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 443 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 444 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 445 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 446 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 447 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 448 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 449 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 450 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 451 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 452 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 453 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 454 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 455 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 456 Combination: (0.2, 10, 'closest', 'log-defined', 'FSeq', 'ROPE', 0.01, True, True, True)
# ...
# Inversion using FSlin with ROPE, reg=l2, alpha=0.07
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -3.628, 'RMSE': 0.188, '0R2': -0.966, '0RMSE': 0.258}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -7.311, 'RMSE': 0.252, '0R2': -1.51, '0RMSE': 0.298}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -5.141, 'RMSE': 0.216, '0R2': -1.257, '0RMSE': 0.284}]
# Iteration: 3446 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, True, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15542.13it/s]
# Constrained inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -3.556, 'RMSE': 0.185, '0R2': -0.33, '0RMSE': 0.228}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -6.515, 'RMSE': 0.242, '0R2': -0.741, '0RMSE': 0.256}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -2.765, 'RMSE': 0.164, '0R2': -0.268, '0RMSE': 0.219}]
# Iteration: 3447 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, True, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15386.29it/s]
# Inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -3.574, 'RMSE': 0.189, '0R2': -0.96, '0RMSE': 0.261}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -6.778, 'RMSE': 0.251, '0R2': -1.412, '0RMSE': 0.292}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -4.522, 'RMSE': 0.206, '0R2': -1.156, '0RMSE': 0.278}]
# Iteration: 3448 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, True, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15120.06it/s]
# Constrained inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -3.129, 'RMSE': 0.174, '0R2': -0.512, '0RMSE': 0.239}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -6.112, 'RMSE': 0.232, '0R2': -0.929, '0RMSE': 0.27}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -2.147, 'RMSE': 0.149, '0R2': -0.37, '0RMSE': 0.23}]
# Iteration: 3449 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, True, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<?, ?it/s]
# Inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -3.383, 'RMSE': 0.188, '0R2': -1.058, '0RMSE': 0.264}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -6.886, 'RMSE': 0.249, '0R2': -1.6, '0RMSE': 0.302}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -4.969, 'RMSE': 0.212, '0R2': -1.347, '0RMSE': 0.283}]
# Iteration: 3450 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, False, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<?, ?it/s]
# Constrained inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -3.421, 'RMSE': 0.184, '0R2': -0.702, '0RMSE': 0.252}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -6.565, 'RMSE': 0.236, '0R2': -1.116, '0RMSE': 0.276}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -2.35, 'RMSE': 0.162, '0R2': -0.596, '0RMSE': 0.244}]
# Iteration: 3451 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, False, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15397.59it/s]
# Inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -3.968, 'RMSE': 0.195, '0R2': -1.132, '0RMSE': 0.274}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -7.706, 'RMSE': 0.259, '0R2': -1.7, '0RMSE': 0.306}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -5.876, 'RMSE': 0.221, '0R2': -1.392, '0RMSE': 0.292}]
# Iteration: 3452 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, False, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 14536.64it/s]
# Constrained inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -4.451, 'RMSE': 0.196, '0R2': -0.488, '0RMSE': 0.238}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -5.788, 'RMSE': 0.227, '0R2': -0.734, '0RMSE': 0.252}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -2.803, 'RMSE': 0.164, '0R2': -0.306, '0RMSE': 0.22}]
# Iteration: 3453 Combination: (0.3, 30, 'closest', 'log-defined', 'FSlin', 'ROPE', 0.2, False, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15416.46it/s]
# Inversion using FSlin with ROPE, reg=l2, alpha=0.2
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -3.673, 'RMSE': 0.192, '0R2': -1.064, '0RMSE': 0.272}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -7.112, 'RMSE': 0.248, '0R2': -1.482, '0RMSE': 0.309}, {'cl': 0.3, 'percent': 30, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'FSlin', 'Minimization_Method': 'ROPE', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -5.131, 'RMSE': 0.217, '0R2': -1.354, '0RMSE': 0.291}]
#      cl  percent Samples location    Interface Forward_Model  \
# 0   0.2       10             mean     Observed          FSeq
# 1   0.2       10             mean     Observed          FSeq
# 2   0.2       10             mean     Observed          FSeq
# 0   0.2       10             mean     Observed          FSeq
# 1   0.2       10             mean     Observed          FSeq
# ..  ...      ...              ...          ...           ...
# 1   0.3       30          closest  log-defined         FSlin
# 2   0.3       30          closest  log-defined         FSlin
# 0   0.3       30          closest  log-defined         FSlin
# 1   0.3       30          closest  log-defined         FSlin
# 2   0.3       30          closest  log-defined         FSlin
#
#    Minimization_Method  Alpha  remove_coil  start_avg  constrain Det     R2  \
# 0         Gauss-Newton   0.01         True       True       True  LT -8.119
# 1         Gauss-Newton   0.01         True       True       True  ID -9.617
# 2         Gauss-Newton   0.01         True       True       True  LS -7.945
# 0         Gauss-Newton   0.01         True       True      False  LT -8.119
# 1         Gauss-Newton   0.01         True       True      False  ID -9.617
# ..                 ...    ...          ...        ...        ...  ..    ...
# 1                 ROPE   0.20        False      False       True  ID -5.788
# 2                 ROPE   0.20        False      False       True  LS -2.803
# 0                 ROPE   0.20        False      False      False  LT -3.673
# 1                 ROPE   0.20        False      False      False  ID -7.112
# 2                 ROPE   0.20        False      False      False  LS -5.131
#
#      RMSE    0R2  0RMSE
# 0   0.260 -1.775  0.315
# 1   0.287 -2.213  0.336
# 2   0.258 -1.836  0.317
# 0   0.260 -1.775  0.315
# 1   0.287 -2.213  0.336
# ..    ...    ...    ...
# 1   0.227 -0.734  0.252
# 2   0.164 -0.306  0.220
# 0   0.192 -1.064  0.272
# 1   0.248 -1.482  0.309
# 2   0.217 -1.354  0.291
#
# [10362 rows x 15 columns]

# %%
from SA_all import SA
import itertools
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np

from plots import *
pd.set_option('display.max_columns', None)

# Define the variables and their possible values
site = 'M'

clls = [0.2, 0.3]
percents = [10, 20, 30]
sample_locs = ['mean', 'closest']
interfaces = ['observed', 'log-defined']
FMs = ['FSeq', 'CS', 'FSlin']
MinMs = ['Gauss-Newton', 'ROPE']
alphas = [0.01, 0.07, 0.2]
remove_coils = [True, False]
start_avgs = [True, False]
constrains = [True, False]

SA_results = 'SA_results/'

file_path_all = 'dt'+site+'_'+str(clls)+'_'+str(percents)+'_'+str(sample_locs)+'_'+str(['obs', 'logd'])+'_'+str(FMs)+'_'+str(['GN', 'ROPE'])+'_'+str(alphas)+'_'+str(['T', 'F'])+'_'+str(['T', 'F'])+'_'+str(['T', 'F'])+'_det'

# Initialize DataFrame
dt = pd.DataFrame()
i = 0  # to keep track of iterations for saving purposes

# Iterate over all combinations
for combination in itertools.product(clls, percents, sample_locs, interfaces, FMs, MinMs, alphas, remove_coils, start_avgs, constrains):

    cl, percent, sample_loc, interface, FM, MinM, alpha, remove_coil, start_avg, constrain = combination
    print('Iteration:', i, 'Combination:', combination)

    file_path = 'dt'+site+'_'+str(cl)+'_'+str(percent)+'_'+str(sample_loc)+'_'+str(interface)+'_'+str(FM)+'_'+str(MinM)+'_'+str(alpha)+'_'+str(remove_coil)+'_'+str(start_avg)+'_'+str(constrain)+'_det'
    SA_file_path = SA_results + file_path+'.csv'
    file_path_FAILED = SA_results + file_path+'_FAILED'+'.csv'

    if os.path.exists(SA_file_path):
        #print('exists')
        SA_file = pd.read_csv(SA_file_path)

    elif os.path.exists(file_path_FAILED):
        #print('exists but failed')

        SA_file_FAILED = pd.read_csv(file_path_FAILED)

    else:
        try:
            # Call the SA function with the current combination
            results = SA(site, cl, percent, sample_loc, interface, FM, MinM, alpha, remove_coil, start_avg, constrain)

            # Create a dictionary for the current iteration's results
            current_results = [{'cl': cl, 'percent': percent, 'Samples location': sample_loc, 'Interface': interface, 'Forward_Model': FM, 'Minimization_Method': MinM, 'Alpha': alpha,
                                'remove_coil': remove_coil, 'start_avg': start_avg, 'constrain': constrain,
                                'Det': det, 'R2': res[0], 'RMSE': res[1], '0R2': res[2], '0RMSE': res[3]}
                            for det, res in zip(['LT', 'ID', 'LS'], [(results[i], results[i+1], results[i+10], results[i+11]) for i in range(0, 6, 2)])]

            print('current_results', current_results)
            SA_file = pd.DataFrame(current_results)
            # Save the DataFrame to CSV after each iteration
            SA_file.to_csv(SA_file_path, index=False)

        except Exception as e:

            # Create a dictionary for the current iteration's results
            current_results = [{'cl': cl, 'percent': percent, 'Samples location': sample_loc, 'Interface': interface, 'Forward_Model': FM, 'Minimization_Method': MinM, 'Alpha': alpha,
                                'remove_coil': remove_coil, 'start_avg': start_avg, 'constrain': constrain,
                                'Det': det, 'R2': np.nan, 'RMSE': np.nan, '0R2': np.nan, '0RMSE': np.nan}
                            for det, res in zip(['LT', 'ID', 'LS'], [(np.nan, np.nan, np.nan, np.nan) for i in range(0, 6, 2)])]
            
            SA_file_FAILED = pd.DataFrame(current_results)
            #print(f"An error occurred: {e} with combination {combination}")
            SA_file_FAILED.to_csv(file_path_FAILED, index=False)

            continue  # Continue to the next iteration even if an error occurs

    #print('SA_file.head()', SA_file.head())
    #print('dt', dt.head())
    # Append current results to the DataFrame
    dt = pd.concat([dt, SA_file])
    i += 1  # Increment the iteration counter

print(dt)
dt.to_csv(SA_results + file_path_all+'.csv')
# Out:
# Iteration: 0 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 1 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 2 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 3 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 4 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 5 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 6 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 7 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 8 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 9 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 10 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 11 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 12 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 13 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 14 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 15 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 16 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 17 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 18 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 19 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 20 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 21 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 22 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 23 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 24 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, True, True)
# Iteration: 25 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, True, False)
# Iteration: 26 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, False, True)
# Iteration: 27 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, True, False, False)
# Iteration: 28 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, True, True)
# Iteration: 29 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, True, False)
# Iteration: 30 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, False, True)
# Iteration: 31 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.01, False, False, False)
# Iteration: 32 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, True, True)
# Iteration: 33 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, True, False)
# Iteration: 34 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, False, True)
# Iteration: 35 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, True, False, False)
# Iteration: 36 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, True, True)
# Iteration: 37 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, True, False)
# Iteration: 38 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, False, True)
# Iteration: 39 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.07, False, False, False)
# Iteration: 40 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, True, True)
# Iteration: 41 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, True, False)
# Iteration: 42 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, False, True)
# Iteration: 43 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, True, False, False)
# Iteration: 44 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, True, True)
# Iteration: 45 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, True, False)
# Iteration: 46 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, False, True)
# Iteration: 47 Combination: (0.2, 10, 'mean', 'observed', 'FSeq', 'ROPE', 0.2, False, False, False)
# Iteration: 48 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 49 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 50 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 51 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 52 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 53 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 54 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 55 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 56 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 57 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 58 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 59 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 60 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 61 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 62 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 63 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 64 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 65 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 66 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 67 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 68 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 69 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 70 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 71 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 72 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, True, True)
# Iteration: 73 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, True, False)
# Iteration: 74 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, False, True)
# Iteration: 75 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, True, False, False)
# Iteration: 76 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, True, True)
# Iteration: 77 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, True, False)
# Iteration: 78 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, False, True)
# Iteration: 79 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.01, False, False, False)
# Iteration: 80 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, True, True)
# Iteration: 81 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, True, False)
# Iteration: 82 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, False, True)
# Iteration: 83 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, True, False, False)
# Iteration: 84 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, True, True)
# Iteration: 85 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, True, False)
# Iteration: 86 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, False, True)
# Iteration: 87 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.07, False, False, False)
# Iteration: 88 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, True, True)
# Iteration: 89 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, True, False)
# Iteration: 90 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, False, True)
# Iteration: 91 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, True, False, False)
# Iteration: 92 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, True, True)
# Iteration: 93 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, True, False)
# Iteration: 94 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, False, True)
# Iteration: 95 Combination: (0.2, 10, 'mean', 'observed', 'CS', 'ROPE', 0.2, False, False, False)
# Iteration: 96 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, True, True)
# Iteration: 97 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, True, False)
# Iteration: 98 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, False, True)
# Iteration: 99 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, True, False, False)
# Iteration: 100 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, True, True)
# Iteration: 101 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, True, False)
# Iteration: 102 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, False, True)
# Iteration: 103 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.01, False, False, False)
# Iteration: 104 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, True, True)
# Iteration: 105 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, True, False)
# Iteration: 106 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, False, True)
# Iteration: 107 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, True, False, False)
# Iteration: 108 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, True, True)
# Iteration: 109 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, True, False)
# Iteration: 110 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, False, True)
# Iteration: 111 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.07, False, False, False)
# Iteration: 112 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, True, True)
# Iteration: 113 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, True, False)
# Iteration: 114 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, False, True)
# Iteration: 115 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, True, False, False)
# Iteration: 116 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, True, True)
# Iteration: 117 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, True, False)
# Iteration: 118 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, False, True)
# Iteration: 119 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'Gauss-Newton', 0.2, False, False, False)
# Iteration: 120 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, True, True)
# Iteration: 121 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, True, False)
# Iteration: 122 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, False, True)
# Iteration: 123 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, True, False, False)
# Iteration: 124 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, True, True)
# Iteration: 125 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, True, False)
# Iteration: 126 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, False, True)
# Iteration: 127 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.01, False, False, False)
# Iteration: 128 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, True, True)
# Iteration: 129 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, True, False)
# Iteration: 130 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, False, True)
# Iteration: 131 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, True, False, False)
# Iteration: 132 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, True, True)
# Iteration: 133 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, True, False)
# Iteration: 134 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, False, True)
# Iteration: 135 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.07, False, False, False)
# Iteration: 136 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, True, True)
# Iteration: 137 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, True, False)
# Iteration: 138 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, False, True)
# Iteration: 139 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, True, False, False)
# Iteration: 140 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, True, True)
# Iteration: 141 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, True, False)
# Iteration: 142 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, False, True)
# Iteration: 143 Combination: (0.2, 10, 'mean', 'observed', 'FSlin', 'ROPE', 0.2, False, False, False)
# Iteration: 144 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -12.918, 'RMSE': 0.186, '0R2': 0.63, '0RMSE': 0.114}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -10.459, 'RMSE': 0.174, '0R2': 0.714, '0RMSE': 0.098}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -12.574, 'RMSE': 0.184, '0R2': 0.616, '0RMSE': 0.117}]
# Iteration: 145 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -12.918, 'RMSE': 0.186, '0R2': 0.63, '0RMSE': 0.114}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -10.459, 'RMSE': 0.174, '0R2': 0.714, '0RMSE': 0.098}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -12.574, 'RMSE': 0.184, '0R2': 0.616, '0RMSE': 0.117}]
# Iteration: 146 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -12.918, 'RMSE': 0.186, '0R2': 0.63, '0RMSE': 0.114}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -10.459, 'RMSE': 0.174, '0R2': 0.714, '0RMSE': 0.098}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -12.574, 'RMSE': 0.184, '0R2': 0.616, '0RMSE': 0.117}]
# Iteration: 147 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, True, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -12.918, 'RMSE': 0.186, '0R2': 0.63, '0RMSE': 0.114}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -10.459, 'RMSE': 0.174, '0R2': 0.714, '0RMSE': 0.098}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -12.574, 'RMSE': 0.184, '0R2': 0.616, '0RMSE': 0.117}]
# Iteration: 148 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -12.823, 'RMSE': 0.192, '0R2': 0.144, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -13.244, 'RMSE': 0.19, '0R2': 0.162, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -12.896, 'RMSE': 0.194, '0R2': 0.085, '0RMSE': 0.188}]
# Iteration: 149 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -12.823, 'RMSE': 0.192, '0R2': 0.144, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -13.244, 'RMSE': 0.19, '0R2': 0.162, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -12.896, 'RMSE': 0.194, '0R2': 0.085, '0RMSE': 0.188}]
# Iteration: 150 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -12.823, 'RMSE': 0.192, '0R2': 0.144, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -13.244, 'RMSE': 0.19, '0R2': 0.162, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -12.896, 'RMSE': 0.194, '0R2': 0.085, '0RMSE': 0.188}]
# Iteration: 151 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.01, False, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -12.823, 'RMSE': 0.192, '0R2': 0.144, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -13.244, 'RMSE': 0.19, '0R2': 0.162, '0RMSE': 0.181}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -12.896, 'RMSE': 0.194, '0R2': 0.085, '0RMSE': 0.188}]
# Iteration: 152 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -15.614, 'RMSE': 0.204, '0R2': 0.647, '0RMSE': 0.108}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -13.224, 'RMSE': 0.19, '0R2': 0.786, '0RMSE': 0.092}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -15.248, 'RMSE': 0.202, '0R2': 0.641, '0RMSE': 0.108}]
# Iteration: 153 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -15.614, 'RMSE': 0.204, '0R2': 0.647, '0RMSE': 0.108}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -13.224, 'RMSE': 0.19, '0R2': 0.786, '0RMSE': 0.092}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -15.248, 'RMSE': 0.202, '0R2': 0.641, '0RMSE': 0.108}]
# Iteration: 154 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -15.614, 'RMSE': 0.204, '0R2': 0.647, '0RMSE': 0.108}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -13.224, 'RMSE': 0.19, '0R2': 0.786, '0RMSE': 0.092}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -15.248, 'RMSE': 0.202, '0R2': 0.641, '0RMSE': 0.108}]
# Iteration: 155 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, True, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -15.614, 'RMSE': 0.204, '0R2': 0.647, '0RMSE': 0.108}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -13.224, 'RMSE': 0.19, '0R2': 0.786, '0RMSE': 0.092}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -15.248, 'RMSE': 0.202, '0R2': 0.641, '0RMSE': 0.108}]
# Iteration: 156 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -14.481, 'RMSE': 0.197, '0R2': 0.822, '0RMSE': 0.08}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -11.564, 'RMSE': 0.178, '0R2': 0.941, '0RMSE': 0.046}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -14.292, 'RMSE': 0.194, '0R2': 0.817, '0RMSE': 0.081}]
# Iteration: 157 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -14.481, 'RMSE': 0.197, '0R2': 0.822, '0RMSE': 0.08}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -11.564, 'RMSE': 0.178, '0R2': 0.941, '0RMSE': 0.046}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -14.292, 'RMSE': 0.194, '0R2': 0.817, '0RMSE': 0.081}]
# Iteration: 158 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -14.481, 'RMSE': 0.197, '0R2': 0.822, '0RMSE': 0.08}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -11.564, 'RMSE': 0.178, '0R2': 0.941, '0RMSE': 0.046}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -14.292, 'RMSE': 0.194, '0R2': 0.817, '0RMSE': 0.081}]
# Iteration: 159 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.07, False, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -14.481, 'RMSE': 0.197, '0R2': 0.822, '0RMSE': 0.08}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -11.564, 'RMSE': 0.178, '0R2': 0.941, '0RMSE': 0.046}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.07, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -14.292, 'RMSE': 0.194, '0R2': 0.817, '0RMSE': 0.081}]
# Iteration: 160 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -18.141, 'RMSE': 0.216, '0R2': 0.438, '0RMSE': 0.138}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -16.387, 'RMSE': 0.208, '0R2': 0.542, '0RMSE': 0.132}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -18.01, 'RMSE': 0.216, '0R2': 0.432, '0RMSE': 0.138}]
# Iteration: 161 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -18.141, 'RMSE': 0.216, '0R2': 0.438, '0RMSE': 0.138}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -16.387, 'RMSE': 0.208, '0R2': 0.542, '0RMSE': 0.132}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -18.01, 'RMSE': 0.216, '0R2': 0.432, '0RMSE': 0.138}]
# Iteration: 162 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -18.141, 'RMSE': 0.216, '0R2': 0.438, '0RMSE': 0.138}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -16.387, 'RMSE': 0.208, '0R2': 0.542, '0RMSE': 0.132}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -18.01, 'RMSE': 0.216, '0R2': 0.432, '0RMSE': 0.138}]
# Iteration: 163 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, True, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -18.141, 'RMSE': 0.216, '0R2': 0.438, '0RMSE': 0.138}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -16.387, 'RMSE': 0.208, '0R2': 0.542, '0RMSE': 0.132}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -18.01, 'RMSE': 0.216, '0R2': 0.432, '0RMSE': 0.138}]
# Iteration: 164 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -15.594, 'RMSE': 0.203, '0R2': 0.788, '0RMSE': 0.084}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -13.418, 'RMSE': 0.191, '0R2': 0.929, '0RMSE': 0.051}, {'cl': 0.2, 'percent': 10, 'Samples location': 'mean', 'Interface': 'log-defined', 'Forward_Model': 'FSeq', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -15.482, 'RMSE': 0.202, '0R2': 0.794, '0RMSE': 0.084}]
# Iteration: 165 Combination: (0.2, 10, 'mean', 'log-defined', 'FSeq', 'Gauss-Newton', 0.2, False, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 15/15 inverted#################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# ...
# 15/15 inverted
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -16.835, 'RMSE': 0.207, '0R2': 0.42, '0RMSE': 0.147}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -14.584, 'RMSE': 0.196, '0R2': 0.5, '0RMSE': 0.138}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -16.965, 'RMSE': 0.209, '0R2': 0.38, '0RMSE': 0.152}]
# Iteration: 494 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'Gauss-Newton', 0.2, False, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# Survey 1/1
# 15/15 inverted
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -16.835, 'RMSE': 0.207, '0R2': 0.42, '0RMSE': 0.147}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -14.584, 'RMSE': 0.196, '0R2': 0.5, '0RMSE': 0.138}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -16.965, 'RMSE': 0.209, '0R2': 0.38, '0RMSE': 0.152}]
# Iteration: 495 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'Gauss-Newton', 0.2, False, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# Survey 1/1
# 15/15 inverted
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -16.835, 'RMSE': 0.207, '0R2': 0.42, '0RMSE': 0.147}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -14.584, 'RMSE': 0.196, '0R2': 0.5, '0RMSE': 0.138}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'Gauss-Newton', 'Alpha': 0.2, 'remove_coil': False, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -16.965, 'RMSE': 0.209, '0R2': 0.38, '0RMSE': 0.152}]
# Iteration: 496 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, True, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 14813.88it/s]
# Constrained inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -19.328, 'RMSE': 0.23, '0R2': -0.669, '0RMSE': 0.254}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -16.353, 'RMSE': 0.216, '0R2': -0.538, '0RMSE': 0.244}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -18.525, 'RMSE': 0.225, '0R2': -0.602, '0RMSE': 0.248}]
# Iteration: 497 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, True, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15022.58it/s]
# Inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -0.844, 'RMSE': 0.066, '0R2': -0.145, '0RMSE': 0.209}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -1.639, 'RMSE': 0.082, '0R2': -0.212, '0RMSE': 0.208}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -1.08, 'RMSE': 0.071, '0R2': -0.19, '0RMSE': 0.211}]
# Iteration: 498 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, True, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 12847.57it/s]
# Constrained inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -18.475, 'RMSE': 0.224, '0R2': -0.546, '0RMSE': 0.248}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -17.19, 'RMSE': 0.216, '0R2': -0.454, '0RMSE': 0.24}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -17.872, 'RMSE': 0.221, '0R2': -0.508, '0RMSE': 0.245}]
# Iteration: 499 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, True, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 14993.94it/s]
# Inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LT', 'R2': -0.97, 'RMSE': 0.072, '0R2': -0.092, '0RMSE': 0.208}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'ID', 'R2': -1.822, 'RMSE': 0.084, '0R2': -0.163, '0RMSE': 0.206}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': True, 'start_avg': False, 'constrain': False, 'Det': 'LS', 'R2': -1.1, 'RMSE': 0.075, '0R2': -0.129, '0RMSE': 0.211}]
# Iteration: 500 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, False, True, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15018.99it/s]
# Constrained inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LT', 'R2': -15.816, 'RMSE': 0.205, '0R2': -0.619, '0RMSE': 0.248}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'ID', 'R2': -12.342, 'RMSE': 0.187, '0R2': -0.483, '0RMSE': 0.236}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': True, 'Det': 'LS', 'R2': -15.308, 'RMSE': 0.201, '0R2': -0.6, '0RMSE': 0.246}]
# Iteration: 501 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, False, True, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 14997.51it/s]
# Inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LT', 'R2': -5.005, 'RMSE': 0.124, '0R2': -0.888, '0RMSE': 0.28}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'ID', 'R2': -6.169, 'RMSE': 0.13, '0R2': -0.985, '0RMSE': 0.282}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': True, 'constrain': False, 'Det': 'LS', 'R2': -5.021, 'RMSE': 0.125, '0R2': -0.92, '0RMSE': 0.281}]
# Iteration: 502 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, False, False, True)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 13609.03it/s]
# Constrained inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################
# current_results [{'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LT', 'R2': -11.32, 'RMSE': 0.173, '0R2': -0.154, '0RMSE': 0.214}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'ID', 'R2': -10.966, 'RMSE': 0.174, '0R2': -0.15, '0RMSE': 0.211}, {'cl': 0.2, 'percent': 10, 'Samples location': 'closest', 'Interface': 'log-defined', 'Forward_Model': 'CS', 'Minimization_Method': 'ROPE', 'Alpha': 0.01, 'remove_coil': False, 'start_avg': False, 'constrain': True, 'Det': 'LS', 'R2': -10.782, 'RMSE': 0.168, '0R2': -0.139, '0RMSE': 0.214}]
# Iteration: 503 Combination: (0.2, 10, 'closest', 'log-defined', 'CS', 'ROPE', 0.01, False, False, False)
# ##################################################################################################################################################################### 02 INVERSION CONFIGURE INPUT ################################################
# 100%|██████████| 15/15 [00:00<00:00, 15029.76it/s]
# Inversion using CS with ROPE, reg=l2, alpha=0.01
# #################################################################################################################################################################### 03 DETERMINISTIC MODELLING ###################################################

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
from plots import *
from plots import *
indicator = 'R2'

# Example usage
file_path_all_ = str(clls)+'_'+str(percents)+'_'+str(sample_locs)+'_'+str(['obs', 'logd'])+'_'+str(FMs)+'_'+str(['GN', 'ROPE'])+'_'+str(alphas)+'_'+str(['T', 'F'])+'_'+str(['T', 'F'])+'_'+str(['T', 'F'])+'_det'

SA_plot(file_path_all_, SA_results, indicator)

# %%
import pandas as pd
import os
from plots import *
from plots import *
import itertools
import pandas as pd
import os
import numpy as np

pd.set_option('display.max_columns', None)

# Define the variables and their possible values
site = 'P'

clls = [0.2, 0.3, 0.4]
percents = [10, 20, 30]
sample_locs = ['mean', 'closest']
#interfaces = ['Observed', 'Log-defined']
FMs = ['FSeq', 'CS', 'FSlin']
MinMs = ['Gauss-Newton', 'ROPE']
alphas = [0.01, 0.07, 0.2]
remove_coils = [True, False]
start_avgs = [True, False]
constrains = [True, False]

SA_results = 'SA_results/'

i = 0  # to keep track of iterations for saving purposes
# Iterate over all combinations
for combination in itertools.product(clls, percents, sample_locs, FMs, MinMs, alphas, remove_coils, start_avgs, constrains):

    cl, percent, sample_loc, FM, MinM, alpha, remove_coil, start_avg, constrain = combination
    print('Iteration:', i, 'Combination:', combination)

    file_path_new = 'dt'+site+'_'+str(cl)+'_'+str(percent)+'_'+str(sample_loc)+'_Observed'+'_'+str(FM)+'_'+str(MinM)+'_'+str(alpha)+'_'+str(remove_coil)+'_'+str(start_avg)+'_'+str(constrain)+'_det'    
    file_path = 'dt'+site+'_'+str(cl)+'_'+str(percent)+'_'+str(sample_loc)+'_'+str(FM)+'_'+str(MinM)+'_'+str(alpha)+'_'+str(remove_coil)+'_'+str(start_avg)+'_'+str(constrain)+'_det'    
    SA_file_path = SA_results + file_path+'.csv'
    file_path_FAILED = SA_results + file_path+'_FAILED'+'.csv'

    SA_file_path_new = SA_results + file_path_new+'.csv'
    file_path_FAILED_new = SA_results + file_path_new+'_FAILED'+'.csv'

    if os.path.exists(SA_file_path):
        SA_file = pd.read_csv(SA_file_path)
        if 'Interface' not in SA_file.columns:
            SA_file.insert(3, 'Interface', 'Observed')
        SA_file.to_csv(SA_file_path_new, index=False)

    elif os.path.exists(file_path_FAILED):
        SA_file_FAILED = pd.read_csv(file_path_FAILED)
        if 'Interface' not in SA_file_FAILED.columns:
            SA_file_FAILED.insert(3, 'Interface', 'Observed')
        SA_file_FAILED.to_csv(file_path_FAILED_new, index=False)

    i += 1  # Increment the iteration counter

# %%
import pandas as pd
import os
from plots import *
from plots import *
import itertools
import pandas as pd
import os
import numpy as np

pd.set_option('display.max_columns', None)

# Define the variables and their possible values
site = 'M'

clls = [0.2, 0.3, 0.4]
percents = [10, 20, 30]
sample_locs = ['mean', 'closest']
#interfaces = ['Observed', 'Log-defined']
FMs = ['FSeq', 'CS', 'FSlin']
MinMs = ['Gauss-Newton', 'ROPE']
alphas = [0.01, 0.07, 0.2]
remove_coils = [True, False]
start_avgs = [True, False]
constrains = [True, False]

data_inv_folder = 'data/inverted/'

i = 0  # to keep track of iterations for saving purposes
# Iterate over all combinations
for combination in itertools.product(clls, percents, sample_locs, FMs, MinMs, alphas, remove_coils, start_avgs, constrains):

    cl, percent, sample_loc, FM, MinM, alpha, remove_coil, start_avg, constrain = combination
    print('Iteration:', i, 'Combination:', combination)

    file_path = 'proefhoeve_21HS_inverted_samples'+'_'+str(cl)+'_'+str(percent)+'_'+str(sample_loc)+'_'+str(FM)+'_'+str(MinM)+'_'+str(alpha)+'_'+str(remove_coil)+'_'+str(start_avg)+'_'+str(constrain)
    file_path_new = 'proefhoeve_21HS_inverted_samples'+'_'+str(cl)+'_'+str(percent)+'_'+str(sample_loc)+'_Observed'+'_'+str(FM)+'_'+str(MinM)+'_'+str(alpha)+'_'+str(remove_coil)+'_'+str(start_avg)+'_'+str(constrain)

    data_inv_path = data_inv_folder + file_path+'.csv'
    data_inv_path_new = data_inv_folder + file_path_new+'.csv'

    #file_path_FAILED = SA_results + file_path+'_FAILED'+'.csv'

    #SA_file_path_new = SA_results + file_path_new+'.csv'
    #file_path_FAILED_new = SA_results + file_path_new+'_FAILED'+'.csv'

    if os.path.exists(data_inv_path):
        inv_file = pd.read_csv(data_inv_path)
        inv_file.to_csv(data_inv_path_new, index=False)
        i += 1
#    elif os.path.exists(file_path_FAILED):
#        SA_file_FAILED = pd.read_csv(file_path_FAILED)
#        cols = list(SA_file_FAILED.columns)
#        cols.remove('Interface')
#        cols.insert(3, 'Interface')
#        SA_file_FAILED = SA_file_FAILED[cols]
#        SA_file_FAILED['Interface'] = 'Observed'
#        SA_file_FAILED.to_csv(file_path_FAILED, index=False)

#    i += 1  # Increment the iteration counter

# %%
# %load_ext autoreload

# Packages -----------------
import os
import sys
import shutil
import warnings
import datetime
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from scipy import constants
from matplotlib.path import Path

# Get notebook and parent dir
current_dir = os.path.dirname(os.path.abspath('__file__')) 
parent_dir = os.path.dirname(current_dir)

# Set path to pedophysics module 
pedophysics_code_path = os.path.join(parent_dir)
sys.path.insert(0, pedophysics_code_path)

import pedophysics
from pedophysics import predict, Soil
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from scipy.optimize import root
from scipy.stats import spearmanr
from scipy.optimize import minimize, differential_evolution
from IPython.display import clear_output
from utils.spatial_utils import utm_to_epsg, get_coincident
#!pip install pymel
import pymel
from FDEM import Initialize
from utils.profile_utils import merge_layers, plot_profile, check_uniformity_and_interpolate

from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from scipy.stats import pearsonr
from PyPDF2 import PdfMerger
from emagpy import Problem

# Electromagnetic induction data inversion package
from plots import *
from PM import *
# %matplotlib inline

pd.set_option('display.max_columns', None)
pd.options.future.infer_string = True

sys.path.insert(0,'../src/') # this add the emagpy/src directory to the PATH

# %% [markdown]
# ## Pedophysical modelling

# %%
# Datetime for filename
now = (datetime.datetime.now())
now = now.strftime("%y%m%d_%H%M")

# User input
s_site = 'M'; # P = Proefhoeve; M = Middelkerke
# Define input datatype and source folder
em_intype = 'rec'   # 'rec' = rECa transect; 'lin' = LIN ECa transect; 
                    # 'survey' = rEC full survey

config = {}

config['instrument_code'] = 'Dualem-21HS' # instrument code

cal = 'calibrated' # 'non_calibrated', 'drift_calibrated'
instrument_code = '21HS' # 421S, '21HS'

# User input

datafolder = 'data' # data folder

if s_site == 'P':
    profile_prefix = 'proefhoeve'
    if config['instrument_code'] == 'Dualem-21HS':
        emfile_prefix = 'proefhoeve_21HS'
    else: 
        emfile_prefix = 'proefhoeve_421S'
        
else:
    profile_prefix = 'middelkerke'
    emfile_prefix = 'middelkerke_421S'
    # check if correct instrument (only 421S data available for Middelkerke)
    if config['instrument_code'] == 'Dualem-21HS':
        config['instrument_code'] = 'Dualem-421S'

# %%
# Data import dry down experiment
dry_down = os.path.join(datafolder, f'Dry_down.csv')
dry_d = pd.read_csv(dry_down, sep=',', header=0)

cal_folder = os.path.join(datafolder, 'calibrated')
em_survey = os.path.join(cal_folder, f'{emfile_prefix}_calibrated_rECa.csv')
em_survey = pd.read_csv(em_survey, sep=',', header=0)
sampleprop = os.path.join(datafolder, f'{profile_prefix}_soil_analysis.csv')
samples_analysis = pd.read_csv(sampleprop, sep=',', header=0)

em_sample_prop = get_coincident(em_survey, samples_analysis)
ds_c = em_sample_prop.copy()

inverted_data = False # Include inverted data or not

if inverted_data:
    inverted = os.path.join(datafolder, f'{profile_prefix}_inverted_samples_{instrument_code}c.csv')
    ds_inv = pd.read_csv(inverted, sep=',', header=0)
    print(ds_inv.head())

    inv_columns = ds_inv.columns[3:-1]
    ds_c[inv_columns] = np.nan

    for idc, c in enumerate(inv_columns):

        for i in range(len(ds_inv.x)):
            ds_c.loc[ds_c.code == i+1, c] = ds_inv.loc[i, c]

    def closest_ec(row):
        depth = row['depth']
        # Filter columns that start with 'EC_' but not 'EC_end'
        ec_cols = [col for col in row.index if col.startswith('EC_') and col != 'EC_end']
        # Convert the part after 'EC_' to float and calculate the absolute difference with depth
        differences = {col: abs(depth/100 - float(col.split('_')[1])) for col in ec_cols}
        # Find the column name with the minimum difference
        closest_col = min(differences, key=differences.get)
        return row[closest_col]


    # Apply the function to each row
    ds_c['bulk_ec_inv'] = ds_c.apply(closest_ec, axis=1)

    #Obtain EC DC TC
    ds_c['bulk_ec_dc_tc_inv'] = predict.BulkECDCTC(Soil(temperature = ds_c.temp.values+273.15,
                                                        frequency_ec = 9e3,
                                                        bulk_ec = ds_c.bulk_ec_inv.values/1000))
    # Mean of input inverted EC DC TC values
    EC_mean = np.mean(ds_c['bulk_ec_dc_tc_inv'].values)

# %% [markdown]
# # Deterministic modelling

# %%
# Caclculate Bulk EC from HydraProbe data at 50Mhz
offset = 4
water_perm = 80
ds_c['bulk_ec_hp'] = logsdon(50e6, ds_c.rperm, ds_c.iperm)

ds_c['bulk_ec_dc_hp'] = predict.BulkECDC(Soil(frequency_ec = 50e6,
                                              bulk_ec = ds_c.bulk_ec_hp.values))

ds_c['bulk_ec_tc_hp'] = SheetsHendrickxEC( ds_c.bulk_ec_hp, ds_c.temp)
ds_c['bulk_ec_dc_tc_hp'] = predict.BulkECDCTC(Soil(temperature = ds_c.temp.values,
                                                    bulk_ec_dc = ds_c.bulk_ec_dc_hp.values
                                                    ))

# Caclculate Water EC from HydraProbe data at 50Mhz
ds_c['water_ec_hp'] = Hilhorst(ds_c.bulk_ec_hp, ds_c.rperm, water_perm, offset)
ds_c['water_ec_hp_t'] = WraithOr(ds_c.water_ec_hp, ds_c.temp)
ds_c['iperm_water_t'] = ds_c.water_ec_hp_t/(50e6*2*pi*epsilon_0)

# -------------------------------------------------------------------------------------

# DRY DOWN experiment
dry_d['P_top_EC'] = logsdon(50e6, dry_d.P_top_RP, dry_d.P_top_IP)
dry_d['P_bot_EC'] = logsdon(50e6, dry_d.P_bot_RP, dry_d.P_bot_IP)
dry_d['M_top_EC'] = logsdon(50e6, dry_d.M_top_RP, dry_d.M_top_IP)
dry_d['M_bot_EC'] = logsdon(50e6, dry_d.M_bot_RP, dry_d.M_bot_IP)

dry_d['P_top_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.P_top_EC.values,
                                          water = dry_d.P_top_W.values,
                                          temperature = dry_d.P_top_T.values+273.15))

dry_d['P_bot_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.P_bot_EC.values,
                                          water = dry_d.P_bot_W.values,
                                          temperature = dry_d.P_bot_T.values+273.15))

dry_d['M_top_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.M_top_EC.values,
                                          water = dry_d.M_top_W.values,
                                          temperature = dry_d.M_top_T.values+273.15))

dry_d['M_bot_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.M_bot_EC.values,
                                          water = dry_d.M_bot_W.values,
                                          temperature = dry_d.M_bot_T.values+273.15))

# DRY DOWN experiment
dry_d['P_top_EC'] = logsdon(50e6, dry_d.P_top_RP, dry_d.P_top_IP)
dry_d['P_bot_EC'] = logsdon(50e6, dry_d.P_bot_RP, dry_d.P_bot_IP)
dry_d['M_top_EC'] = logsdon(50e6, dry_d.M_top_RP, dry_d.M_top_IP)
dry_d['M_bot_EC'] = logsdon(50e6, dry_d.M_bot_RP, dry_d.M_bot_IP)

dry_d['P_top_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.P_top_EC.values,
                                          water = dry_d.P_top_W.values,
                                          temperature = dry_d.P_top_T.values+273.15))

dry_d['P_bot_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.P_bot_EC.values,
                                          water = dry_d.P_bot_W.values,
                                          temperature = dry_d.P_bot_T.values+273.15))

dry_d['M_top_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.M_top_EC.values,
                                          water = dry_d.M_top_W.values,
                                          temperature = dry_d.M_top_T.values+273.15))

dry_d['M_bot_ECw'] = predict.WaterEC(Soil(bulk_ec_dc = dry_d.M_bot_EC.values,
                                          water = dry_d.M_bot_W.values,
                                          temperature = dry_d.M_bot_T.values+273.15))

if profile_prefix == 'proefhoeve':
    water_ec_10cm = dry_d.P_top_ECw.values[0]
    water_ec_50cm = dry_d.P_bot_ECw.values[0]
    water_ec_mean = (water_ec_10cm + water_ec_50cm)/2

elif profile_prefix == 'middelkerke':
    water_ec_10cm = dry_d.M_top_ECw.values[0]
    water_ec_50cm = dry_d.M_bot_ECw.values[0]
    water_ec_mean = (water_ec_10cm + water_ec_50cm)/2

###################

# -------------------------------------------------------------------------------------

clay_50cm = np.mean(ds_c.clay[ds_c['depth']==50])
clay_10cm = np.mean(ds_c.clay[ds_c['depth']==10])
bd_50cm = np.mean(ds_c.bd[ds_c['depth']==50])
bd_10cm = np.mean(ds_c.bd[ds_c['depth']==10])
water_ec_hp_50cm = np.mean(ds_c.water_ec_hp[ds_c['depth']==50])
water_ec_hp_10cm = np.mean(ds_c.water_ec_hp[ds_c['depth']==10])
water_ec_hp_50cm_t = np.mean(ds_c.water_ec_hp_t[ds_c['depth']==50])
water_ec_hp_10cm_t = np.mean(ds_c.water_ec_hp_t[ds_c['depth']==10])
clay_mean = np.mean(ds_c.clay)
bd_mean = np.mean(ds_c.bd)
water_ec_hp_mean = np.mean(ds_c.water_ec_hp)
water_ec_hp_mean_t = np.mean(ds_c.water_ec_hp_t)
temp_50cm = np.mean(ds_c.temp[ds_c['depth']==50])
temp_10cm = np.mean(ds_c.temp[ds_c['depth']==10])
temp_mean = np.mean(ds_c.temp)
vwc_50cm = np.mean(ds_c.vwc[ds_c['depth']==50])
vwc_10cm = np.mean(ds_c.vwc[ds_c['depth']==10])
vwc_mean = np.mean(ds_c.vwc) # 0.289 Proef

f_ec = 9000
t_conv = 273.15
t_mean_conv = temp_mean+t_conv # 297.28 Proef

# Mean of observed water values
VWC_mean = np.mean(ds_c['vwc'].values) # 0.2891 Proef

# %%
# Predicted water based on mean input inverted EC DC TC values
water_upper = 0.05
water_default = 0
water_lower = -0.05
water_upper_p = 5
water_default_p = 0
water_lower_p = -5

def EC_diff(EC, vwc_diff):

    VWC_mean_pred = predict.Water(Soil(
                                        bulk_ec = EC,  
                                        frequency_ec=f_ec,
                                        clay = clay_mean,
                                        bulk_density = bd_mean,
                                        water_ec = water_ec_mean,
                                        temperature = t_mean_conv
                                    ))[0] 

    return ((VWC_mean_pred - VWC_mean) - vwc_diff)**2

# EC expected
EC_5 = minimize(EC_diff, 0.01, args=(water_upper), bounds= [(0, 1)], method='Nelder-Mead')
EC_upper = EC_5.x[0]

EC_0 = minimize(EC_diff, 0.01, args=(water_default), bounds= [(0, 1)], method='Nelder-Mead')
EC_00 = EC_0.x[0]

EC_n5 = minimize(EC_diff, 0.01, args=(water_lower), bounds= [(0, 1)], method='Nelder-Mead')
EC_lower = EC_n5.x[0]

print(EC_upper, EC_lower, EC_00)

# Difference percentual
EC_upper_p = 100*(EC_upper - EC_00)/EC_00
EC_lower_p = 100*(EC_00 - EC_lower)/EC_00
print(EC_upper_p, EC_lower_p)

sens_pedm_upper = water_upper_p/EC_upper_p
sens_pedm_lower = water_lower_p/EC_lower_p
print(sens_pedm_upper, sens_pedm_lower)

# %%
temp_dir = 'temp_emp_04' 
infile_name = 'infile_s04.csv'
os.makedirs(temp_dir, exist_ok=True)
temp_file = os.path.join(temp_dir,infile_name)

filename = f"{now}_{emfile_prefix}_parameters_04.json"
filepath = os.path.join(temp_dir,filename)
file = open(filepath, 'w')

file.write('\t"EC_00":"{}",'.format(EC_00) + '\n')
file.write('\t"EC_upper_p":"{}",'.format(EC_upper_p) + '\n')
file.write('\t"EC_lower_p":"{}",'.format(EC_lower_p) + '\n')

file.write('\t"sens_pedm_upper":"{}",'.format(sens_pedm_upper) + '\n')
file.write('\t"sens_pedm_lower":"{}",'.format(sens_pedm_lower) + '\n')

# %% [markdown]
# # Inversion: configure  input

# %%
# Sensor settings
config['instrument_code'] = 'Dualem-21HS' # instrument code
config['instrument_height'] = 0.165     # instrument height
config['instrument_orientation'] = 'HCP'    # instrument orientation

# Remove coils for inversion?
config['remove_coil'] = True    # set to True if you want to remove coils in the inversion process
config['coil_n'] = [4,5]    # indexes of coils to remove (cf. emagpy indexing)
                            # for Proefhoeve, coils 0 (HCP05) and 1 (PRP06) are best
                            # removed, for Middelkerke coils 4 (HCP4.0) and 5 (PRP4.1)

# Inversion parameters
config['fs_emp'] = 'FSeq' #'CS', 'FSlin' or 'FSeq'
config['opt_method'] = 'L-BFGS-B'  # mMinimize = ['L-BFGS-B','TNC','CG','Nelder-Mead'] --> https://docs.scipy.org/doc/scipy/reference/optimize.html 
                                # mMCMC = ['ROPE','DREAM', 'MCMC'] # ??? 'SCEUA' ??? --> https://spotpy.readthedocs.io/en/latest/ 
                                # mOther = ['ANN','Gauss-Newton','GPS'] (ANN requires tensorflow)
config['constrain']=True
config['regularization'] = 'l2'
config['alpha'] = 0.07

# Reference profile for starting model (conductivity values)
config['start_avg'] = False     # take average of input resistivity profiles per layer as starting model
                                # if false, reference profile is taken as starting model

# Define the interfaces depths between layers for starting model and inversion
#           (number of layers = len(config['interface'])+1)
config['n_int'] = True # if True custom interfaces are defined (via config['interface']), 
                        # otherwise reference profile interfaces are used

config['interface'] = [0.3, 
                       0.6, 
                       1.0,
                       2.0
                        ] # depths to custom model interfaces
# Inversion constraining

config['custom_bounds'] = True
config['bounds'] = [(10, 55), (20, 120), (50, 335), (50, 250), (10, 50)]

# remove profiles at transect edges
config['n_omit'] =  10 # number of profiles to exclude from the start
                       # and end of the ERT transect (none = 0) for the inversion
                       # a total of 60 profiles is available, for middelkerke
                       # 120 profiles are available 

if config['constrain']:
    if config['custom_bounds']:
        bounds = config['bounds']

if config['n_int'] == False and config['custom_bounds']:
    print('Check if bounds and number of interfaces match')

# Geographic operations (if needed)
c_transform = False
c_utmzone = '31N'
c_target_cs = 'EPSG:31370'

# ---------------------------------------------------------------------------- #
# ---------------------------------------------------------------------------- #

# Datetime for filename
now = (datetime.datetime.now())
now = now.strftime("%y%m%d_%H%M")

# %% [markdown]
# ## Load data

# %%
# ---------------------------------------------------------------------------- #
# ---------------------------------------------------------------------------- #

if s_site == 'P':
    profile_prefix = 'proefhoeve'
    if config['instrument_code'] == 'Dualem-21HS':
        emfile_prefix = 'proefhoeve_21HS'
    else: 
        emfile_prefix = 'proefhoeve_421S'
else:
    profile_prefix = 'middelkerke'
    emfile_prefix = 'middelkerke_421S'
    # check if correct instrument (only 421S data available for Middelkerke)
    if config['instrument_code'] == 'Dualem-21HS':
        config['instrument_code'] = 'Dualem-421S'

inv_folder = os.path.join(datafolder, 'inverted')
os.makedirs(inv_folder, exist_ok=True) 
cal_folder = os.path.join(datafolder, 'calibrated')
ert_file = os.path.join(datafolder, f'{profile_prefix}-profiles.csv')
em_rec = os.path.join(cal_folder, f'{emfile_prefix}_transect_calibrated_rECa.csv')
em_lin = os.path.join(cal_folder,f'{emfile_prefix}_transect_calibrated_LIN.csv')
em_survey = os.path.join(cal_folder, f'{emfile_prefix}_calibrated_rECa.csv')
samplocs = os.path.join(datafolder, f'{profile_prefix}_samps.csv')

if em_intype == 'rec':
    infile = em_rec
elif em_intype == 'survey':
    infile = em_survey
else:
    infile = em_lin

instrument = Initialize.Instrument(config['instrument_code'],
                                    instrument_height=config['instrument_height'],
                                    instrument_orientation=config['instrument_orientation']
                                    )

# Column names for emapgy input
emp_21HS = [f"HCP0.5f9000{config['instrument_height']}", 'PRP0.6f9000h0.165', 'HCP1.0f9000h0.165', 'PRP1.1f9000h0.165',	'HCP2.0f9000h0.165', 'PRP2.1f9000h0.165',
            'HCP0.5f9000h0.165_inph', 'PRP0.6f9000h0.165_inph', 'HCP1.0f9000h0.165_inph',
            'PRP1.1f9000h0.165_inph', 'HCP2.0f9000h0.165_inph', 'PRP2.1f9000h0.165_inph'
            ]

emp_421S = ['HCP1.0f9000h0.165', 'PRP1.1f9000h0.165',	'HCP2.0f9000h0.165', 'PRP2.1f9000h0.165', 'HCP4.0f9000h0.165', 'PRP4.1f9000h0.165', 
            'HCP1.0f9000h0.165_inph', 'PRP1.1f9000h0.165_inph', 'HCP2.0f9000h0.165_inph', 'PRP2.1f9000h0.165_inph',
            'HCP4.0f9000h0.165_inph', 'PRP4.1f9000h0.165_inph',
            ]

if config['opt_method'] == 'Gauss-Newton':
    config['regularization'] = 'l2'

# Datetime for filename
now = (datetime.datetime.now())
now = now.strftime("%y%m%d_%H%M")

# 1.0 Data import and structuring into dataframe
ert_p = pd.read_csv(ert_file, sep=',', header=0)
em_rec = pd.read_csv(em_rec, sep=',', header=0)
em_lin = pd.read_csv(em_lin, sep=',', header=0)
em_survey = pd.read_csv(em_survey, sep=',', header=0)
samples = pd.read_csv(samplocs, sep=',', header=0)


if c_transform:
    # Create a new filename with the target EPSG code
    em_rec = utm_to_epsg(em_rec, c_utmzone, target_epsg=c_target_cs)
    em_lin = utm_to_epsg(em_lin, c_utmzone, target_epsg=c_target_cs)
    em_survey = utm_to_epsg(em_survey, c_utmzone, target_epsg=c_target_cs)

instrument = Initialize.Instrument(config['instrument_code'],
                                    instrument_height=config['instrument_height'],
                                        instrument_orientation=config['instrument_orientation']
                                        )

em_samples = get_coincident(em_survey,samples)

# ---------------------------------------------------------------------------- #
# Get ERT profiles
# ---------------- #
# Group the data by profile ID for efficient access to each profile
profiles = ert_p.groupby('ID')

# Exclude the first and last n_omit profiles
unique_ids = ert_p['ID'].unique()

if config['n_omit'] == 0:
    ert_final = ert_p.copy()
else:
    if config['n_omit']*2 >= len(unique_ids):
        warnings.warn('!!! You removed all profiles !!! Change value for config[n_omit]')
        raise KeyboardInterrupt
    else:
        selected_ids = unique_ids[config['n_omit']:-config['n_omit']]
        ert_p = ert_p.loc[ert_p['ID'].isin(selected_ids)]
        ert_final = ert_p.copy()

dataset_name = 'Resistivity(ohm.m)'  # The variable of interest

# convert resistivity to conductivity and modify column names

ert_final[dataset_name] = (1/ert_final[dataset_name])
dc_corr = ert_final.copy()
dc_corr[dataset_name] = predict.BulkEC(Soil(
                                                frequency_ec = 9000,
                                                bulk_ec_dc = dc_corr[dataset_name].values
                                                ))

ert_final.loc[:, dataset_name] = ert_final[dataset_name]*1000
dc_corr.loc[:,dataset_name] = dc_corr[dataset_name]*1000
ert_final = ert_final.rename(columns={"Resistivity(ohm.m)": "EC(mS/m)"})
dc_corr = dc_corr.rename(columns={"Resistivity(ohm.m)": "EC(mS/m)"})

# ------------------------------------------------------------------------------

# Columns containing the resistivity data
data_column = ['EC(mS/m)']
# Assuming ert_final is your DataFrame with profile data
all_profiles_df, uniform_intervals = check_uniformity_and_interpolate(
    dc_corr, 'ID', 'z', *data_column
)

dataset_name = 'EC(mS/m)'  # The variable of interest

# %%
config['reference_profile'] = 11

if config['reference_profile'] not in all_profiles_df['ID'].unique():
    warnings.warn("Warning: the reference profile ID does not exist. Provide correct profile ID.")
    raise KeyboardInterrupt
else:
    profile_id = config['reference_profile']

# Create new layer configuration for prior model based on ERT data
if config['n_int']:
    new_int = config['interface']
    merged_df = merge_layers(all_profiles_df, new_int,'EC(mS/m)')
else:
    merged_df = all_profiles_df
comparedf = merged_df.copy()

# Plot original and (merged and) DC corrected reference profile
if config['n_int']:
    plot_title = 'Original vs merged & DC corrected data'
    first_in = .1
else: 
    plot_title = 'Original vs DC corrected data'
    first_in = .0
ert_eval = ert_final.copy()
ert_eval['z'] = ert_eval['z'].values + first_in

plot_profile(ert_eval, profile_id, dataset_name, compare=True, compare_df = comparedf, compare_name = 'EC(mS/m)', block=True, plot_title=plot_title)

# Get prior model info
def generate_forward_model_inputs(df, profile_id_col, depth_col, res_col):
    models = {}  # Dictionary to store models by profile ID

    for profile_id, group in df.groupby(profile_id_col):
        # Assuming uniform interval after previous interpolation
        uniform_interval = abs(group[depth_col].diff().iloc[1])
        #print(uniform_interval)
        num_layers = len(group[res_col])
                # Thicknesses are the intervals between depths, except for the last value which does not define a new layer
        thick = np.full(num_layers - 1, uniform_interval)
        thick[0] = 2 * thick[0]
        # Conductivity is the inverse of resistivity
        con = group[res_col].values/1000
        # Permittivity is the epsilon_0 for all layers
        perm = np.full(num_layers, constants.epsilon_0)
        sus = np.zeros(num_layers)
        # Create model instance
        M = Initialize.Model(thick, sus[::-1], con[::-1], perm[::-1])
        
        # Store the model instance in the dictionary with the profile ID as the key
        models[profile_id] = M
    return models

models = generate_forward_model_inputs(merged_df, 'ID', 'z', 'EC(mS/m)')

# %%
# 
# -------------------------------------------------------------------- #

# 
profile_data = merged_df[merged_df['ID'] == profile_id].copy()
res_col = 'EC(mS/m)'
depth = 'z'
max_ert_depth = ert_final['z'].abs().max()

# 
# ------------------------------------------------------------------------------

# A. Test run on the reference profile (config['reference_profile'])
#       and plot the results

if not config['n_int']:
    first_lay = profile_data[depth].iloc[-1].round(decimals=1)
    second_lay = profile_data[depth].iloc[-2].round(decimals=1)
    if first_lay == 0:
        profile_data[depth]=profile_data[depth] +second_lay
    else:
        profile_data[depth]=profile_data[depth] +first_lay
    thick = -profile_data[depth].iloc[1:].values
    #thick = -profile_data[depth].values
else:
    thick = -profile_data[depth].values

con = profile_data[res_col].values/1000
ref_len = len(con)
num_layers = len(con)
perm = np.full(num_layers, constants.epsilon_0)
sus = np.zeros(num_layers)

# # Create model instance
M = Initialize.Model(thick, sus[::-1], con[::-1], perm[::-1])

# ----------------------------------------------------------------------

dataset_name = 'EC(mS/m)'
layers_interfaces = np.cumsum(models[profile_id].thick)
layers_interfaces = np.insert(layers_interfaces, 0, 0)
profile_data = ert_final[ert_final['ID'] == profile_id]

fig, axr = plt.subplots(figsize=(5, 10))
axr.set_xlabel('EC [mS/m]')
axr.set_ylabel('depth [m]')
axr.plot((profile_data[dataset_name]),profile_data['z'], label='original (DC) ERT EC',)
if not config['n_int']: 
    axr.plot(con[:-1]*1000,-thick, '.', label='Model EC 9khz',color = 'red')
else:
    axr.plot(con*1000,-thick, '.', label='Model EC 9khz',color = 'red')
axr.set_title(f'Reference profile: ID {profile_id}')

conductivities = con*1000
print('conductivities', conductivities)

ec_cols_ref = []
if 'end' in config['interface']:
    config['interface'].remove('end')
# Get conductivity stats for bounds
if config['n_int']:
    if 'end' in ec_cols_ref:
        ec_cols_ref.remove('end')
    ec_cols_ref = config['interface']
    ec_cols_ref.append('end')
    mod_layers = thick[1:]
else:
    if len(conductivities) == len(thick):
        mod_layers = thick[1:]
        print(f"length modlayers = {len(mod_layers)} with {len(conductivities)} conductivities")
    elif len(conductivities) == (len(thick)+1):
        mod_layers = thick
        print(f"length modlayers = {len(mod_layers)} with {len(conductivities)} conductivities")
    else:
        raise ValueError(f"Check length of conductivities ({len(conductivities)}) and layers ({len(thick)}) arrays!!")
    
    ec_cols_ref = np.round(layers_interfaces,decimals=1).tolist()
ec_df = pd.DataFrame(columns=ec_cols_ref)

# 
for i in merged_df['ID'].unique(): 
    profile_data = merged_df[merged_df['ID'] == i].copy()
    if not config['n_int']:
        if abs(profile_data.iloc[0]['z']) > max((list(map(abs, ec_cols_ref)))):
            #print(f'removed {profile_data.iloc[0]["z"]}')
            profile_data = profile_data.drop(profile_data.iloc[0].name)
        elif abs(profile_data.iloc[-1]['z']) < 0.1:
            #print(f'removed {profile_data.iloc[-1]["z"]}')
            profile_data = profile_data.drop(profile_data.iloc[-1].name)
    res_col = 'EC(mS/m)'
    depth = 'z' 
    con_m = profile_data[res_col].values
    layers_interfaces = np.cumsum(models[i].thick)
    layers_interfaces = np.insert(layers_interfaces, 0, 0)
    num_layers = len(con)
    perm = np.full(num_layers, constants.epsilon_0)
    sus = np.zeros(num_layers)

    first_lay = profile_data[depth].iloc[-1].round(decimals=1)
    second_lay = profile_data[depth].iloc[-2].round(decimals=1)

    if not config['n_int']:
        first_lay = profile_data[depth].iloc[-1].round(decimals=1)
        second_lay = profile_data[depth].iloc[-2].round(decimals=1)
        if first_lay == 0:
            profile_data[depth]=profile_data[depth] +second_lay
        else:
            profile_data[depth]=profile_data[depth] +first_lay
        thick = -profile_data[depth].iloc[1:].values
    else:
        thick = -profile_data[depth].values

    ec_df = pd.concat([ec_df, pd.DataFrame([np.flip(con_m)], columns=ec_cols_ref)])

ec_df.reset_index(drop=True, inplace=True)

ec_stats = ec_df.describe().loc[['min', 'max', 'std', '50%', 'mean']]
ec_stats.rename(index={'50%': 'median'}, inplace=True)
ec_stats.loc['min_sd'] = ec_stats.loc['min'] - 2 * ec_stats.loc['std']
ec_stats.loc['max_sd'] = ec_stats.loc['max'] + 2 * ec_stats.loc['std']

position = -thick


# define parameters for inversion starting model
# --------------------------------------------- #

if not config['n_int']:
    minstat = np.flipud(ec_stats.loc['min'].values[1:])
    maxstat = np.flipud(ec_stats.loc['max'].values[1:])
    start_mod = ec_stats.loc['mean'].values[1:]
    boundcols = ec_cols_ref[:-1]
else:
    minstat = np.flipud(ec_stats.loc['min'].values)
    maxstat = np.flipud(ec_stats.loc['max'].values)
    start_mod = ec_stats.loc['mean'].values

axr.plot(np.flipud(start_mod),position, 
            '*', 
            label='average conductivity',
            color = 'green',
            alpha = 0.5)
axr.plot(minstat,position, 
            '.', 
            label='min',
            color = 'black',
            alpha = 0.2)
axr.plot(maxstat,position, 
            '+', 
            label='max',
            color = 'black',
            alpha = 0.25)

axr.legend()
if config['constrain']:
    if config['custom_bounds']:
        bounds = config['bounds']
    else:
        bounds = []
        for i, name in enumerate(ec_cols_ref):
            if ec_stats.loc['min_sd'][name] > 0:
                min = ec_stats.loc['min_sd'][name]
            elif ec_stats.loc['min'][name] > 0:
                min = ec_stats.loc['min'][name]
            else:
                min = 10
            max = ec_stats.loc['max_sd'][name]
            min_max = tuple([min,max])
            bounds.append(min_max)
        bounds = np.round(bounds, decimals=0)
        if not config['n_int'] and not config['custom_bounds']:
            bounds = bounds[1:]
        print(f'autobounds = {bounds}')

# %%
# Perform inversion on sampling locations (to be used in pedophysical modelling)

if 'code' in em_samples.columns:
    em_samples = em_samples.rename(columns={'code': 'ID'})

i = instrument.niter
n = 4
em_samples.columns.values[n:n+i]

if config['instrument_code'] == 'Dualem-21HS':
    new_columns = emp_21HS
else:
    new_columns = emp_421S

if len(new_columns) != i:
    raise ValueError("The length of new_columns must be equal to the number of columns to rename")
else:
    em_samples.columns.values[n:n+i] = new_columns

em_samples.to_csv(temp_file)

# transect inversion settings

s_rec = Problem()
s_rec.createSurvey(temp_file)
#t_rec.rollingMean(window=12)

s_rec.setInit(
    depths0=np.flipud(mod_layers),
    conds0=conductivities
    )

if config['remove_coil']:
    if type(config['coil_n']) == list:
        config['coil_n'] = sorted(config['coil_n'])
        for i in enumerate(config['coil_n']):
            r_coil = s_rec.coils[(config['coil_n'][i[0]]-i[0])]
            # print(f'removing {r_coil}')
            s_rec.removeCoil(config['coil_n'][i[0]]-i[0])
    else:
        s_rec.removeCoil(config['coil_n'])

print(f'Data used for inversion: {s_rec.coils}')

# %%
# invert using ROPE solver (RObust Parameter Estimation)
warnings.filterwarnings('ignore')
opt_meth = config['opt_method']
inv_meth = config['fs_emp']
reg_meth = config['regularization']
alph_param = config['alpha']
if opt_meth in ['MCMC', 'ROPE']:
    if config['constrain']:
        
        print(f'Constrained inversion using {inv_meth} with {opt_meth}, reg={reg_meth}, alpha={alph_param}')
        s_rec.invert(forwardModel=config['fs_emp'], method=opt_meth, 
                regularization=reg_meth, alpha=alph_param, 
                bnds=bounds
                )

    else:
        print(f'Inversion using {inv_meth} with {opt_meth}, reg={reg_meth}, alpha={alph_param}')
        s_rec.invert(forwardModel=config['fs_emp'], method=opt_meth, 
        regularization=reg_meth, alpha=alph_param, njobs=-1
        )

else:
    print(f'Inversion using {inv_meth} with {opt_meth}, reg={reg_meth}, alpha={alph_param}')
    s_rec.invert(forwardModel='FSeq', method='Gauss-Newton', alpha=alph_param,regularization=reg_meth)
s_rec.showOne2one()

# %%
# 4.1: Plot the inversion results and put outcomes into a pandas dataframe
# ------------------------------------------------------------------------
csv_filename = f'{now}_{emfile_prefix}_inverted_samples_{opt_meth}_04.csv'

# ******************************************************************** #

# Plot inversion outcomes down to a max depth of 2 m, and plotting the data
# based on their true coordinates along the transect (dist=True).
s_rec.showResults(dist=True, errorbar = True) 

# Extracting the values from the first row of the transect.depths[0] array
depth_values = s_rec.depths[0][0]

# Creating the custom column names for layer_cols
layer_cols = ['EC_{:.2f}'.format(d) for d in depth_values] + ['EC_end']

# Combining the data from the 'x', 'y' columns and the transect.models[0] array
data = np.c_[s_rec.surveys[0].df[['x', 'y']].values, s_rec.models[0]]

# Creating the final dataframe with the desired column names
ds_inv = pd.DataFrame(data, columns=['x', 'y'] + layer_cols)
ds_inv['pos'] = em_samples['ID'].to_numpy()
# ----------------------------------------------------------------------

# Export the dataframe as a csv-file
outfile_transect = os.path.join(inv_folder, csv_filename)
ds_inv.to_csv(outfile_transect)

# %%
inv_columns = ds_inv.columns[3:-1]
ds_c[inv_columns] = np.nan

for idc, c in enumerate(inv_columns):

    for i in range(len(ds_inv.x)):
        ds_c.loc[ds_c.code == i+1, c] = ds_inv.loc[i, c]

def closest_ec(row):
    depth = row['depth']
    # Filter columns that start with 'EC_' but not 'EC_end'
    ec_cols = [col for col in row.index if col.startswith('EC_') and col != 'EC_end']
    # Convert the part after 'EC_' to float and calculate the absolute difference with depth
    differences = {col: abs(depth/100 - float(col.split('_')[1])) for col in ec_cols}
    # Find the column name with the minimum difference
    closest_col = min(differences, key=differences.get)
    return row[closest_col]

# Apply the function to each row
ds_c['bulk_ec_inv'] = ds_c.apply(closest_ec, axis=1)

#Obtain EC DC TC
ds_c['bulk_ec_dc_tc_inv'] = predict.BulkECDCTC(Soil(temperature = ds_c.temp.values+273.15,
                                                    frequency_ec = 9e3,
                                                    bulk_ec = ds_c.bulk_ec_inv.values/1000))
# Mean of input inverted EC DC TC values
EC_mean = np.mean(ds_c['bulk_ec_dc_tc_inv'].values) 
print('EC_mean', EC_mean)

#### Uncertainty inversion parameters
EC = 0.06980570031133289

### ROPE uncertainty
inv_results = [0.075, 0.069, 0.073, 0.0687, 0.0695, 0.0719, 0.0745, 0.0709, 0.0644, 0.0708]

ROPE_inv_upper_p = 100*(-EC + np.max(inv_results))/(np.max(inv_results))
ROPE_inv_lower_p = 100*(-EC + np.min(inv_results))/(np.min(inv_results))
print('ROPE_inv_upper_p, ROPE_inv_lower_p', ROPE_inv_upper_p, ROPE_inv_lower_p)

### Alpha uncertainty
Alpha_upper = np.inf
Alpha_lower = 0.001
Alpha = 0.07

Alpha_upper_p = 100*(Alpha_upper - Alpha)/Alpha
Alpha_lower_p = 100*(-Alpha + Alpha_lower)/Alpha
print('Alpha_upper_p, Alpha_lower_p', Alpha_upper_p, Alpha_lower_p)

sens_alpha_upper = EC_upper_p/Alpha_upper_p
sens_alpha_lower = EC_lower_p/Alpha_lower_p
print('sens_alpha_upper, sens_alpha_lower', sens_alpha_upper, sens_alpha_lower)

# %%
file.write('\t"EC_mean":"{}",'.format(EC_mean) + '\n')
file.write('\t"ROPE_inv_upper_p":"{}",'.format(ROPE_inv_upper_p) + '\n')
file.write('\t"ROPE_inv_lower_p":"{}",'.format(ROPE_inv_lower_p) + '\n')

file.write('\t"input file + path": "{}",'.format(infile) + '\n\n')
file.write('\t"instrument": "{}",'.format(config['instrument_code'] ) + '\n')
file.write('\t"instrument mode": "{}",'.format(config['instrument_orientation']) + '\n')
file.write('\t"instrument height (m)": {:.3f},'.format(config['instrument_height']) + '\n')

if config['remove_coil']:
    rem_coils = instrument.cc_names[config['coil_n']]
    file.write('\t"configurations not used in inversion": "{}",'.format(rem_coils) + '\n\n')

file.write('\t"forward model": "{}",'.format(config['fs_emp']) + '\n')
file.write('\t"optimisation method":"{}",'.format(config['opt_method']) + '\n')
file.write('\t"regularisation": "{}",'.format(config['regularization']) + '\n')
file.write('\t"alpha parameter": "{}",'.format(alph_param) + '\n\n')
file.write('\t"reference EC profile":"{}",'.format(config['reference_profile']) + '\n')

if config['constrain']:
    file.write('\t "constrained inversion":' + '\n')
    if config['n_int']:
        file.write('\t"custom interface boundaries": "{}"\n'.format(config['interface']) + '\n')
    if config['custom_bounds']:
        file.write('\t"custom inversion constraints (bnds)": "{}" \n'.format(config['bounds']) + '\n')
    else:
        file.write('\t"automated inversion constraints (bnds)": "{}"\n'.format(bounds) + '\n')

file.close()
